# %%
from fastai import *
from fastai.vision import *
import numpy as np
import os

# %%
path = os.getcwd() + '/datasets'
path = Path(path)
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train= 'train', valid_pct=0.2, num_workers=8, bs=256)

# %%
learn = cnn_learner(data, models.resnet34, metrics=[accuracy, error_rate])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/arrowhead/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %%
data.show_batch(rows=3, figsize=(9,9))
